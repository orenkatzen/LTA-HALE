# %%
from gpkit import Model, Variable, units
import gpkit
from numpy import pi, tan
import math
from __future__ import division
gpkit.settings["latex_modelname"] = False

class ltaHALE(Model):
    def setup(self):

        constraints = []

        # Constants
        g = Variable('g', 9.81,'m/s^2', 'gravitational constant')
        R_earth = Variable('R_{earth}', 6371*10^3, 'meters', 'radius of the earth')
        R = Variable('R', 287, 'J/kg*K', 'ideal gas constant')

        # Requirements
        m_pay = Variable('m_{pay}', 10, 'lb', 'mass of payload') 
        Thresh_Diameter = Variable('Thresh_{diam}', 100, 'km', 'threshold footprint diameter')
        Object_Diameter = Variable('Object_{diam}', 300, 'km', 'objective footprint diameter')
        Inclination_Angle = Variable('angle_{incl}', 5, 'deg', 'max antenna inclination angle')
        time = Variable('t', 5, 'days', 'flight time')
        P_payload = Variable('P_{pay}', 10, 'W', 'power requirement of payload')

        # Assumptions
        Cd = Variable('C_d', 0.2, '-', 'drag coefficient') #Sphere
        eta_prop = Variable(r'\eta_{prop}', 0.75, '-', 'propulsive efficiency')
        m_bat = Variable('m_{bat}', 2, 'kg', 'mass of payload battery')
        m_avi = Variable('m_{avi}', 1, 'kg', 'mass of avionics')
        m_fixed = Variable('m_{fixed}', 'lbm', 'fixed mass')

        constraints.extend([m_fixed >= m_pay + m_avi + m_bat])

        f_fixed_pay = Variable('f_{weightMassFraction}', 0.1, '-', 'Fixed weight mass fraction')

        W = Variable('W', 'lbf', 'vehicle weight')
        W_diesel = Variable('W_{diesel}', 'lbf', 'mission diesel fuel weight')
        m_balloon = Variable('m_balloon', 'kg', 'mass of balloon skin')
        vol = Variable('vol', 'm^3', 'vehicle Volume')
        rho_he = Variable(r'\rho_{he}', 0.1786, 'g/L', 'density of helium at stp')
        m_engine = Variable('m_engine', 'kg', 'mass of engine')
        constraints.extend([W >= m_fixed * g + W_diesel + m_balloon * g + vol * rho_he * g+m_engine*g])

#         # # Atmospheric Stuff -- MATLAB syntax
#         T=zeros(1,30000); # Celsius Temperature Matrix 
#         P=zeros(1,30000); # Kilopascal Pressure Matrix
#         for h=1:30000
#             if h<11000
#                 T(1,h)=15.04-0.00649*h;
#                 P(1,h)=101.29*((T(1,h)+273.1)/288.08)^5.256;
#             elseif h<25000 && h>=11000
#                 T(1,h)=-56.46;
#                 P(1,h)=22.65*exp(1.73-0.000157*h);
#             elseif h>=25000
#                 T(1,h)=-131.21+0.00299*h;
#                 P(1,h)=2.488*((T(1,h)+273.1)/216.6)^-11.388;
#             end
#         end

#         p=P./(0.2869.*(T+273.1)); # # kg/m^3 Density Matrix
#         h=1:30000;

#         Altitude of Flight accounting for Curvature of the Earth (Assumed Spherical Earth)
#         Footprint = Variable('D', 'm', 'Diameter of Communications Footprint')
#         Theta = Variable(r'\Theta', Footprint / (4 * pi * R_earth) * 2*math.pi, 'rad', 'theta')
#         Chord_earth = Variable('Chord_{earth}', 2 * R_earth * math.sin(Theta/2), 'm', 'chord length of the earth')
#         Alpha = Variable(r'\Alpha', (math.pi - Theta)/2, 'deg', 'alpha')
#         Beta = Variable(r'\Beta', math.pi - Alpha, 'rad', 'beta')
#         Zeta = Variable(r'\Zeta', math.pi/2 - Alpha, 'rad', 'zeta')
#         Gamma = Variable(r'\Gamma', math.pi - Beta - Inclination_Angle - Zeta, 'rad', 'gamma')
        

#         constraints.extend([Footprint>=Object_Diameter, 
#                 H >= Chord_earth * math.sin(Inclination_Angle + Zeta)/math.sin(Gamma)]); # # meters

#         # # Environment
        rho = Variable(r'\rho','kg/m^3', 'air density')
#         press = P(1,H); # pressure for this selected altitude
#         temp = T(1,H); # # temperature for this selected altitude
        h = Variable("h", "km", "Altitude")
        vel = Variable('vel', 'm/s', 'cruise velocity')
        v_wind = Variable('v_{wind}', 'm/s', 'wind velocity')
        conversion = Variable('conversion',835.29,'m/s*km**(1.409)','wind velocity coversion to m/s')

        constraints.extend([vel >= v_wind,
                           v_wind>=conversion*h**(-1.409)])
        
#         constraints.extend([v_wind>=-0.175*h**2+4.25*h+5])  upside down parabola model of wind with altitude. 

#         # # LTA Sizing
        t = Variable('thickness ratio', 0.5, '-', 'thickness ratio')
        c = Variable('chord', 'm', 'length of vehicle')
        constraints.extend([c >= (vol/(10 * pi * t * (2/3 * 0.2969 - 0.126 * 0.5 - 0.3516 * 1/3 + 0.2843 * 1/4 - 0.1015 * 1/5)))**(1/3)])
        area_front = Variable('area_{front}', 'm^2', 'frontal area')
        area_surface = Variable('area_{surface}', 'm^2', 'surface area')
        r = Variable('r', 'm', 'vehicle radius')
        rho_he = Variable(r'\rho_{he}', 'g/L', 'density of helium at altitude')
        R_he = Variable('R_{he}', 2077, 'J/(kg * K)', 'specific gas constant for helium')
        rho_h = Variable(r'\rho_{h}', 'g/L', 'density of hydrogen at altitude')
        R_h = Variable('R_{h}', 4124, 'J/(kg * K)', 'specific gas constant for hydrogen')
        t_skin = Variable('t_{skin}', 0.005, 'in', 'thickness of skin of balloon')
        rho_skin = Variable(r'\rho_{skin}', 1.45, 'g/cm^3', 'density of polyester skin')
        constraints.extend([vol >= W/(rho * g),
                            r == t * c/2,
                            area_front == pi * r**2,
                            area_surface == 4 * pi * r**2,
                            m_balloon == t_skin* area_surface * rho_skin])

        # Power Consumption
        P_shaft = Variable('P_{shaft}', 'W', 'Shaft power')
        PtoW = Variable('PtoW', 109, 'W/kg', 'engine power to weight ratio') # https://en.wikipedia.org/wiki/Power-to-weight_ratio Toyota Venza
        Diesel_eff = Variable(r'\Eta_{diesel}', 0.5, '-', 'diesel engine efficiency')
        constraints.extend([P_shaft >= 1 /eta_prop/2. * rho * vel**3 * Cd * area_front,
                            m_engine >= P_shaft / (PtoW * Diesel_eff)])

        E_total = Variable('E_{total}', "MJ", "total mission energy")

#         # Carbon Fuels
        h_diesel = Variable('h_{diesel}', 35.86, 'MJ/L', 'diesel energy density')
        Diesel_dens = Variable(r'\Rho_{diesel}', 0.832, 'kg/L', 'diesel density')
        constraints.extend([W_diesel >= E_total/h_diesel*Diesel_dens*g,
                            E_total >= (P_payload + P_shaft)*time])
#         Gasoline_Edens = Variable('gasoline_{edens}', 32.4, 'MJ/L', 'gasoline energy density')
#         Gasoline_eff = Variable(r'\Eta_{gasoline}', 0.25, '-', 'gasoline engine efficiency')
#         Gasoline_dens = Variable(r'\Rho_{gasoline}', 0.75, 'kg/L', 'gasoline density')
#         Jetfuel_Edens = Variable('jetfuel_{edens}', 37.4, 'MJ/L', 'jetfuel energy density')
#         Jetfuel_dens = Variable(r'\Rho_{jetfuel}', 0.81, 'kg/L', 'jetfuel density')
#         constraints.extend([Diesel_needed >= E_total_joules/(Diesel_Edens * 10^6),
#                             Gasoline_needed >= E_total_joules/(Gasoline_Edens * 10^6),
#                             Jetfuel_needed >= E_total_joules/(Jetfuel_Edens * 10^6),
#                             Diesel_mass >= Diesel_needed*Diesel_dens,
#                             Gasoline_mass >= Gasoline_needed * Gasoline_dens,
#                             Jetfuel_mass >= Jetfuel_needed * Jetfuel_dens,
#                             Diesel_fraction >= Diesel_mass/(W/g),
#                             Gasoline_fraction >= Gasoline_mass/(W/g),
#                             Jetfuel_fraction >= Jetfuel_mass/(W/g)])

        # Atmosphere model
        
        p_sl = Variable("p_{sl}", 101325, "Pa", "Pressure at sea level")
        T_sl = Variable("T_{sl}", 288.15, "K", "Temperature at sea level")
        L_atm = Variable("L_{atm}", 0.0065, "K/m", "Temperature lapse rate")
        T_atm = Variable("T_{atm}", "K", "air temperature")
        M_atm = Variable("M_{atm}", 0.0289644, "kg/mol", "Molar mass of dry air")
        R_atm = Variable("R_{atm}", 8.31447, "J/mol/K")
        TH = (g*M_atm/R_atm/L_atm).value.magnitude  # dimensionless
        constraints.extend([h <= 20000*units.m,  # Model valid to top of troposphere
                            h >=14900*units.m, #for footprint
                            T_sl >= T_atm + L_atm*h,     # Temp decreases w/ altitude
                            rho <= p_sl*T_atm**(TH-1)*M_atm/R_atm/(T_sl**TH)])  # http://en.wikipedia.org/wiki/Density_of_air#Altitude
        
        P_atm = Variable('P_{atm}', 'Pa', 'air pressure')
        constraints.extend([P_atm == rho * R_atm/M_atm * T_atm,
                            rho_h == P_atm/(R_h * T_atm),
                            rho_he == P_atm/(R_he * T_atm)])
        
        # station keeping requirement
        footprint = Variable("d_{footprint}", 300, 'km', "station keeping footprint diameter")
        lu = Variable(r"\theta_{look-up}", 5, '-', "look up angle")
        R_earth = Variable("R_{earth}", 6371, "km", "Radius of earth")
        tan_lu = lu*pi/180. + (lu*pi/180.)**3/3.  # Taylor series expansion
        # approximate earth curvature penalty as distance^2/(2*Re)
        constraints.extend([h >= tan_lu*0.5*footprint + footprint**2/8./R_earth])
        
        objective = W

        return objective, constraints

m = ltaHALE()
m.solve('cvxopt')
#m.controlpanel()
# Out:
# Using solver 'cvxopt'
# Solving for 20 variables.
# Solving took 0.0399 seconds.
#
# Cost
# ----
#  1.461e+04 [lbf]
#
# Free Variables
# --------------
#      E_{total} : 1.456e+04  [MJ]      total mission energy
#        P_{atm} : 1.176e+04  [Pa]      air pressure
#      P_{shaft} : 3.368e+04  [W]       Shaft power
#        T_{atm} : 191.3      [K]       air temperature
#              W : 1.461e+04  [lbf]     vehicle weight
#     W_{diesel} : 744.8      [lbf]     mission diesel fuel weight
#           \rho : 0.2141     [kg/m**3] air density
#      \rho_{he} : 0.0296     [g/l]     density of helium at altitude
#       \rho_{h} : 0.01491    [g/l]     density of hydrogen at altitude
#   area_{front} : 184.2      [m**2]    frontal area
# area_{surface} : 736.9      [m**2]    surface area
#          chord : 30.63      [m]       length of vehicle
#              h : 14.9       [km]      Altitude
#      m_balloon : 135.7      [kg]      mass of balloon skin
#       m_engine : 618.1      [kg]      mass of engine
#      m_{fixed} : 16.61      [lb]      fixed mass
#              r : 7.658      [m]       vehicle radius
#       v_{wind} : 18.57      [m/s]     wind velocity
#            vel : 18.57      [m/s]     cruise velocity
#            vol : 3.093e+04  [m**3]    vehicle Volume
#
# Constants
# ---------
#              C_d : 0.2                        drag coefficient
#          L_{atm} : 0.0065     [K/m]           Temperature lapse rate
#          M_{atm} : 0.02896    [kg/mol]        Molar mass of dry air
#          P_{pay} : 10         [W]             power requirement of payload
#             PtoW : 109        [W/kg]          engine power to weight ratio
#          R_{atm} : 8.314      [J/K/mol]
#        R_{earth} : 6371       [km]            Radius of earth
#           R_{he} : 2077       [J/K/kg]        specific gas constant for helium
#            R_{h} : 4124       [J/K/kg]        specific gas constant for hydrogen
#           T_{sl} : 288.1      [K]             Temperature at sea level
#    \Eta_{diesel} : 0.5                        diesel engine efficiency
#    \Rho_{diesel} : 0.832      [kg/l]          diesel density
#      \eta_{prop} : 0.75                       propulsive efficiency
#        \rho_{he} : 0.1786     [g/l]           density of helium at stp
#      \rho_{skin} : 1.45       [g/cm**3]       density of polyester skin
# \theta_{look-up} : 5                          look up angle
#       conversion : 835.3      [km**1.409*m/s] wind velocity coversion to m/s
#    d_{footprint} : 300        [km]            station keeping footprint diameter
#                g : 9.81       [m/s**2]        gravitational constant
#       h_{diesel} : 35.86      [MJ/l]          diesel energy density
#          m_{avi} : 1          [kg]            mass of avionics
#          m_{bat} : 2          [kg]            mass of payload battery
#          m_{pay} : 10         [lb]            mass of payload
#           p_{sl} : 1.013e+05  [Pa]            Pressure at sea level
#                t : 5          [day]           flight time
#         t_{skin} : 0.005      [in]            thickness of skin of balloon
#  thickness ratio : 0.5                        thickness ratio
#
# Sensitivities
# -------------
#         L_{atm} : 30.73   Temperature lapse rate
#       \rho_{he} : 14.87   density of helium at stp
#         R_{atm} : 14.26
#      conversion : 7.719   wind velocity coversion to m/s
# thickness ratio : 3.918   thickness ratio
#             C_d : 2.573   drag coefficient
#               g : 1       gravitational constant
#               t : 0.9092  flight time
#   \Rho_{diesel} : 0.9092  diesel density
#        t_{skin} : 0.3653  thickness of skin of balloon
#     \rho_{skin} : 0.3653  density of polyester skin
#         m_{pay} : 0.01221 mass of payload
#      h_{diesel} : -0.9092 diesel energy density
#   \Eta_{diesel} : -1.664  diesel engine efficiency
#            PtoW : -1.664  engine power to weight ratio
#     \eta_{prop} : -2.573  propulsive efficiency
#          p_{sl} : -14.26  Pressure at sea level
#         M_{atm} : -14.26  Molar mass of dry air
#          T_{sl} : -16.47  Temperature at sea level
# {'constants': {PtoW_ltaHALE13: array(109),
#   h_{diesel}_ltaHALE13: array(35.86),
#   \Rho_{diesel}_ltaHALE13: array(0.832),
#   T_{sl}_ltaHALE13: array(288.15),
#   p_{sl}_ltaHALE13: array(101325),
#   \Eta_{diesel}_ltaHALE13: array(0.5),
#   R_{h}_ltaHALE13: array(4124),
#   t_{skin}_ltaHALE13: array(0.005),
#   thickness ratio_ltaHALE13: array(0.5),
#   conversion_ltaHALE13: array(835.29),
#   R_{atm}_ltaHALE13: array(8.31447),
#   L_{atm}_ltaHALE13: array(0.0065),
#   M_{atm}_ltaHALE13: array(0.0289644),
#   m_{pay}_ltaHALE13: array(10),
#   g_ltaHALE13: array(9.81),
#   R_{he}_ltaHALE13: array(2077),
#   m_{avi}_ltaHALE13: array(1),
#   \rho_{he}_ltaHALE13: array(0.1786),
#   \theta_{look-up}_ltaHALE13: array(5),
#   d_{footprint}_ltaHALE13: array(300),
#   R_{earth}_ltaHALE13: array(6371),
#   P_{pay}_ltaHALE13: array(10),
#   C_d_ltaHALE13: array(0.2),
#   \eta_{prop}_ltaHALE13: array(0.75),
#   m_{bat}_ltaHALE13: array(2),
#   t_ltaHALE13: array(5),
#   \rho_{skin}_ltaHALE13: array(1.45)},
#  'cost': array(14605.081787452647),
#  'freevariables': {E_{total}_ltaHALE13: array(14555.820544817601),
#   \rho_{h}_ltaHALE13: array(0.014905305494482324),
#   P_{shaft}_ltaHALE13: array(33684.02903911392),
#   v_{wind}_ltaHALE13: array(18.570253398772014),
#   T_{atm}_ltaHALE13: array(191.30000000047824),
#   P_{atm}_ltaHALE13: array(11759.111494997576),
#   W_{diesel}_ltaHALE13: array(744.7874072791491),
#   vol_ltaHALE13: array(30926.580115321565),
#   m_{fixed}_ltaHALE13: array(16.61386794325793),
#   m_balloon_ltaHALE13: array(135.69817821274484),
#   vel_ltaHALE13: array(18.57025339892126),
#   h_ltaHALE13: array(14.899999998814323),
#   m_engine_ltaHALE13: array(618.0555788242661),
#   \rho_ltaHALE13: array(0.21413591032658388),
#   W_ltaHALE13: array(14605.081787452647),
#   r_ltaHALE13: array(7.657662384081601),
#   chord_ltaHALE13: array(30.63064953526457),
#   area_{front}_ltaHALE13: array(184.22234348738368),
#   \rho_{he}_ltaHALE13: array(0.02959532010512192),
#   area_{surface}_ltaHALE13: array(736.8893739196587)},
#  'localmodel': 9.46e+142*C_d_ltaHALE13**2.6*L_{atm}_ltaHALE13**31*M_{atm}_ltaHALE13**-14*PtoW_ltaHALE13**-1.7*R_{atm}_ltaHALE13**14*T_{sl}_ltaHALE13**-16*\Eta_{diesel}_ltaHALE13**-1.7*\Rho_{diesel}_ltaHALE13**0.91*\eta_{prop}_ltaHALE13**-2.6*\rho_{he}_ltaHALE13**15*\rho_{skin}_ltaHALE13**0.37*conversion_ltaHALE13**7.7*g_ltaHALE13**1*h_{diesel}_ltaHALE13**-0.91*p_{sl}_ltaHALE13**-14*t_ltaHALE13**0.91*t_{skin}_ltaHALE13**0.37*thickness ratio_ltaHALE13**3.9,
#  'sensitivities': {'monomials': array([  1.00000000e+00,   5.38465940e-03,   1.22122021e-02,
#            2.69232970e-03,   9.09238897e-01,   3.65344261e-01,
#            1.48710497e+01,   2.02891927e-02,   1.66400951e+00,
#            7.71893581e+00,   7.71893581e+00,   5.87664574e+00,
#            1.68299316e+01,   2.01508579e+00,   7.89173154e+00,
#            2.32134913e+00,   4.89432773e+00,   2.90378232e+00,
#            3.26912659e+00,   2.90378295e+00,   3.26912722e+00,
#            2.57297860e+00,   1.66400954e+00,   9.09238915e-01,
#            2.69851644e-04,   9.08969063e-01,   8.07122614e-10,
#            1.98548181e+01,   6.07000706e+01,   3.07307989e+01,
#            1.42569530e+01,   3.07284939e+00,   3.07284939e+00,
#            3.07285065e+00,   3.07285065e+00,   3.07285065e+00,
#            3.07285065e+00,   2.84777473e-07,   3.84159802e-08,
#            7.22901493e-10]),
#   'posynomials': array([  1.00000000e+00,   2.02891912e-02,   1.78299316e+01,
#            7.71893581e+00,   7.71893581e+00,   5.87664574e+00,
#            1.68299316e+01,   2.01508579e+00,   7.89173154e+00,
#            2.32134913e+00,   4.89432773e+00,   2.90378232e+00,
#            3.26912659e+00,   2.90378295e+00,   3.26912722e+00,
#            2.57297860e+00,   1.66400954e+00,   9.09238915e-01,
#            9.09238915e-01,   8.07122614e-10,   1.98548181e+01,
#            9.14308696e+01,   1.42569530e+01,   3.07284939e+00,
#            3.07284939e+00,   3.07285065e+00,   3.07285065e+00,
#            3.07285065e+00,   3.07285065e+00,   3.23916355e-07]),
#   'variables': {PtoW_ltaHALE13: array(-1.6640095406099231),
#    h_{diesel}_ltaHALE13: array(-0.9092389145663445),
#    E_{total}_ltaHALE13: array(0.0),
#    \Rho_{diesel}_ltaHALE13: array(0.9092389145663445),
#    T_{sl}_ltaHALE13: array(-16.47384598552331),
#    p_{sl}_ltaHALE13: array(-14.256952953218386),
#    \Eta_{diesel}_ltaHALE13: array(-1.6640095406099231),
#    \rho_{h}_ltaHALE13: array(0.0),
#    R_{h}_ltaHALE13: array(0.0),
#    t_{skin}_ltaHALE13: array(0.36534426816732424),
#    thickness ratio_ltaHALE13: array(3.9177638289656214),
#    P_{shaft}_ltaHALE13: array(-5.1998516603646294e-11),
#    v_{wind}_ltaHALE13: array(1.7763568394002505e-15),
#    conversion_ltaHALE13: array(7.718935810708314),
#    R_{atm}_ltaHALE13: array(14.256952953218386),
#    L_{atm}_ltaHALE13: array(30.73079894480343),
#    T_{atm}_ltaHALE13: array(-6.0617324493250635e-09),
#    M_{atm}_ltaHALE13: array(-14.256952953218386),
#    P_{atm}_ltaHALE13: array(0.0),
#    m_{pay}_ltaHALE13: array(0.012212202089254805),
#    W_{diesel}_ltaHALE13: array(-1.7956107600802795e-08),
#    g_ltaHALE13: array(1.0000000179345996),
#    R_{he}_ltaHALE13: array(0.0),
#    vol_ltaHALE13: array(5.6712210039222555e-08),
#    m_{fixed}_ltaHALE13: array(1.5220642315960653e-09),
#    m_balloon_ltaHALE13: array(-7.185831485401195e-09),
#    m_{avi}_ltaHALE13: array(0.0026923296988560024),
#    \rho_{he}_ltaHALE13: array(14.871049698999293),
#    \theta_{look-up}_ltaHALE13: array(2.869461778530082e-07),
#    d_{footprint}_ltaHALE13: array(3.623323352724383e-07),
#    R_{earth}_ltaHALE13: array(-3.84159802026536e-08),
#    vel_ltaHALE13: array(4.3015369044496765e-11),
#    h_ltaHALE13: array(5.939826410396782e-09),
#    m_engine_ltaHALE13: array(-3.3149691880396404e-08),
#    \rho_ltaHALE13: array(2.1513457681976433e-11),
#    P_{pay}_ltaHALE13: array(0.00026985164448895346),
#    C_d_ltaHALE13: array(2.572978603583777),
#    \eta_{prop}_ltaHALE13: array(-2.572978603583777),
#    m_{bat}_ltaHALE13: array(0.005384659397712005),
#    W_ltaHALE13: array(2.1508128611458233e-11),
#    t_ltaHALE13: array(0.9092389145663445),
#    r_ltaHALE13: array(-5.329070518200751e-15),
#    \rho_{skin}_ltaHALE13: array(0.36534426816732424),
#    chord_ltaHALE13: array(-2.1509016789877933e-11),
#    area_{front}_ltaHALE13: array(2.1509904968297633e-11),
#    \rho_{he}_ltaHALE13: array(0.0),
#    area_{surface}_ltaHALE13: array(8.881784197001252e-16)}},
#  'sweepvariables': {},
#  'variables': {PtoW_ltaHALE13: array(109),
#   h_{diesel}_ltaHALE13: array(35.86),
#   E_{total}_ltaHALE13: array(14555.820544817601),
#   \Rho_{diesel}_ltaHALE13: array(0.832),
#   T_{sl}_ltaHALE13: array(288.15),
#   p_{sl}_ltaHALE13: array(101325),
#   \Eta_{diesel}_ltaHALE13: array(0.5),
#   \rho_{h}_ltaHALE13: array(0.014905305494482324),
#   R_{h}_ltaHALE13: array(4124),
#   t_{skin}_ltaHALE13: array(0.005),
#   thickness ratio_ltaHALE13: array(0.5),
#   P_{shaft}_ltaHALE13: array(33684.02903911392),
#   v_{wind}_ltaHALE13: array(18.570253398772014),
#   conversion_ltaHALE13: array(835.29),
#   R_{atm}_ltaHALE13: array(8.31447),
#   L_{atm}_ltaHALE13: array(0.0065),
#   T_{atm}_ltaHALE13: array(191.30000000047824),
#   M_{atm}_ltaHALE13: array(0.0289644),
#   P_{atm}_ltaHALE13: array(11759.111494997576),
#   m_{pay}_ltaHALE13: array(10),
#   W_{diesel}_ltaHALE13: array(744.7874072791491),
#   g_ltaHALE13: array(9.81),
#   R_{he}_ltaHALE13: array(2077),
#   vol_ltaHALE13: array(30926.580115321565),
#   m_{fixed}_ltaHALE13: array(16.61386794325793),
#   m_balloon_ltaHALE13: array(135.69817821274484),
#   m_{avi}_ltaHALE13: array(1),
#   \rho_{he}_ltaHALE13: array(0.1786),
#   \theta_{look-up}_ltaHALE13: array(5),
#   d_{footprint}_ltaHALE13: array(300),
#   R_{earth}_ltaHALE13: array(6371),
#   vel_ltaHALE13: array(18.57025339892126),
#   h_ltaHALE13: array(14.899999998814323),
#   m_engine_ltaHALE13: array(618.0555788242661),
#   \rho_ltaHALE13: array(0.21413591032658388),
#   P_{pay}_ltaHALE13: array(10),
#   C_d_ltaHALE13: array(0.2),
#   \eta_{prop}_ltaHALE13: array(0.75),
#   m_{bat}_ltaHALE13: array(2),
#   W_ltaHALE13: array(14605.081787452647),
#   t_ltaHALE13: array(5),
#   r_ltaHALE13: array(7.657662384081601),
#   \rho_{skin}_ltaHALE13: array(1.45),
#   chord_ltaHALE13: array(30.63064953526457),
#   area_{front}_ltaHALE13: array(184.22234348738368),
#   \rho_{he}_ltaHALE13: array(0.02959532010512192),
#   area_{surface}_ltaHALE13: array(736.8893739196587)}}
